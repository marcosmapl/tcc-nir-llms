# %% [markdown]
# # Zero-shot Next Item Recommendation on Movie Lens 100k dataset using Open Large Language Models

# %% [markdown]
# ## Installing required modules

# %%
# !pip install -q -U bitsandbytes

# %%
# !pip install -q -U git+https://github.com/huggingface/transformers.git
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -q -U git+https://github.com/huggingface/accelerate.git

# %%
# !pip install cohere
# !pip install tiktoken
# !pip install uszipcode
# !pip install sentencpiece
# !pip install langchain
# Out:
# Requirement already satisfied: cohere in /home/mark/anaconda3/lib/python3.10/site-packages (4.32)
# Requirement already satisfied: fastavro==1.8.2 in /home/mark/anaconda3/lib/python3.10/site-packages (from cohere) (1.8.2)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from cohere) (3.8.5)
# Requirement already satisfied: importlib_metadata<7.0,>=6.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from cohere) (6.8.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/mark/anaconda3/lib/python3.10/site-packages (from cohere) (1.26.14)
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from cohere) (2.28.1)
# Requirement already satisfied: backoff<3.0,>=2.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from cohere) (2.2.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mark/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere) (1.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/mark/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/mark/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mark/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere) (6.0.4)
# Requirement already satisfied: zipp>=0.5 in /home/mark/anaconda3/lib/python3.10/site-packages (from importlib_metadata<7.0,>=6.0->cohere) (3.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.25.0->cohere) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests<3.0.0,>=2.25.0->cohere) (3.4)
# Requirement already satisfied: tiktoken in /home/mark/anaconda3/lib/python3.10/site-packages (0.5.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/mark/anaconda3/lib/python3.10/site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: requests>=2.26.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from tiktoken) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: uszipcode in /home/mark/anaconda3/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from uszipcode) (1.4.39)
# Requirement already satisfied: attrs in /home/mark/anaconda3/lib/python3.10/site-packages (from uszipcode) (22.1.0)
# Requirement already satisfied: atomicwrites in /home/mark/anaconda3/lib/python3.10/site-packages (from uszipcode) (1.4.0)
# Requirement already satisfied: fuzzywuzzy in /home/mark/anaconda3/lib/python3.10/site-packages (from uszipcode) (0.18.0)
# Requirement already satisfied: sqlalchemy-mate>=1.4.28.3 in /home/mark/anaconda3/lib/python3.10/site-packages (from uszipcode) (1.4.28.4)
# Requirement already satisfied: requests in /home/mark/anaconda3/lib/python3.10/site-packages (from uszipcode) (2.28.1)
# Requirement already satisfied: pathlib-mate in /home/mark/anaconda3/lib/python3.10/site-packages (from uszipcode) (1.2.1)
# Requirement already satisfied: haversine>=2.5.0 in /home/mark/anaconda3/lib/python3.10/site-packages (from uszipcode) (2.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/mark/anaconda3/lib/python3.10/site-packages (from SQLAlchemy>=1.4.0->uszipcode) (2.0.1)
# Requirement already satisfied: prettytable in /home/mark/anaconda3/lib/python3.10/site-packages (from sqlalchemy-mate>=1.4.28.3->uszipcode) (3.9.0)
# Requirement already satisfied: six in /home/mark/anaconda3/lib/python3.10/site-packages (from pathlib-mate->uszipcode) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests->uszipcode) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests->uszipcode) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests->uszipcode) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/mark/anaconda3/lib/python3.10/site-packages (from requests->uszipcode) (2.0.4)
# Requirement already satisfied: wcwidth in /home/mark/anaconda3/lib/python3.10/site-packages (from prettytable->sqlalchemy-mate>=1.4.28.3->uszipcode) (0.2.5)

# %% [markdown]
# ## Installing huggingface hub

# %%
# !pip install --upgrade huggingface_hub

# %% [markdown]
# ## Hugging face install teste

# %%
# !python -c "from huggingface_hub import model_info; print(model_info('gpt2'))"

# %% [markdown]
# Token: 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

# %%
# !huggingface-cli login --token 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

# %%
# from huggingface_hub import notebook_login
# notebook_login()

# %% [markdown]
# ## Load Movie Lens 100k data

# %%
def read_json(file):
    with open(file) as f:
        return json.load(f)

def write_json(data, file):
    with open(file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

data_ml_100k = read_json("ml_100k.json")

# %%
type(data_ml_100k)

# %%
data_ml_100k[0][0]

# %%
len(data_ml_100k)

# %% [markdown]
# ## Movie dictionary

# %%
u_item_dict = {}    # movie dict
u_item_p = 0        # movie idx

for elem in data_ml_100k:
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in u_item_dict:
            u_item_dict[movie] = u_item_p   # bind movie name with movie idx
            u_item_p +=1    # increment movie idx

u_item_len = len(u_item_dict)
u_item_len

# %%
u_item_dict

# %% [markdown]
# ## User similarity matrix
#
# TODO: optimize cosine computing

# %%
user_matrix = [] # user matrix

for i, elem in  enumerate(data_ml_100k):    # iterate over user watched movies
    item_hot_list = [0 for _ in range(u_item_len)]  # create one hot user-movie vector
    seq_list = elem[0].split(' | ')
    for movie in seq_list:  # iterate over each movie and update one hot vector
        item_pos = u_item_dict[movie]
        item_hot_list[item_pos] = 1
    user_matrix.append(item_hot_list)   # add user vector to user matrix

user_matrix = np.array(user_matrix)
user_matrix_sim = np.dot(user_matrix, user_matrix.transpose()) # compute similarity (dot product)
user_matrix_sim

# %% [markdown]
# ## Movie popularity dict

# %%
pop_dict = {}

for elem in data_ml_100k:   # iterate over dataset
    # elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')
    for movie in seq_list:  # iterate over each movie
        if movie not in pop_dict:
              pop_dict[movie] = 0
        pop_dict[movie] += 1 # increment movie popularity

pop_dict

# %% [markdown]
# ## Item similarity matrix

# %%
i_item_dict = {}
i_item_id_list = []
i_item_user_dict = {}
i_item_p = 0

for i, elem in  enumerate(data_ml_100k):
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in i_item_user_dict:
            item_hot_list = [0. for ii in range(len(data_ml_100k))]
            i_item_user_dict[movie] = item_hot_list
            i_item_dict[movie] = i_item_p
            i_item_id_list.append(movie)
            i_item_p+=1
#         item_pos = item_dict[movie]
        i_item_user_dict[movie][i] += 1
#     user_list.append(item_hot_list)

i_item_s_list = []
for item in i_item_id_list:
    i_item_s_list.append(i_item_user_dict[item])
#     print (sum(item_user_dict[item]))

item_matrix = np.array(i_item_s_list)
item_matrix_sim = np.dot(item_matrix, item_matrix.transpose())
item_matrix_sim

# %%
id_list =list(range(0,len(data_ml_100k)))
id_list

# %% [markdown]
# ## Sort UF items function

# %%
### user filtering
def sort_uf_items(target_seq, us, num_u, num_i):

    candidate_movies_dict = {}
    sorted_us = sorted(list(enumerate(us)), key=lambda x: x[-1], reverse=True)[:num_u]
    dvd = sum([e[-1] for e in sorted_us])
    for us_i, us_v in sorted_us:
        us_w = us_v * 1.0/dvd
#         print (us_i)
        us_elem = data_ml_100k[us_i]
#         print (us_elem[0])
#         assert 1==0
        us_seq_list = us_elem[0].split(' | ')#+[us_elem[1]]

        for us_m in us_seq_list:
#             print (f"{us_m} not in {target_seq}, {us_m not in target_seq}")
#             break
            if us_m not in target_seq:
                if us_m not in candidate_movies_dict:
                    candidate_movies_dict[us_m] = 0.
                candidate_movies_dict[us_m]+=us_w

#         assert 1==0

    candidate_pairs = list(sorted(candidate_movies_dict.items(), key=lambda x:x[-1], reverse=True))
#     print (candidate_pairs)
    candidate_items = [e[0] for e in candidate_pairs][:num_i]
    return candidate_items

# %% [markdown]
# ## Sort IF items function

# %%
### item filtering
def soft_if_items(target_seq, num_i, total_i, item_matrix_sim, item_dict):
    candidate_movies_dict = {}
    for movie in target_seq:
#         print('ttt:',movie)
        sorted_is = sorted(list(enumerate(item_matrix_sim[item_dict[movie]])), key=lambda x: x[-1], reverse=True)[:num_i]
        for is_i, is_v in sorted_is:
            s_item = i_item_id_list[is_i]

            if s_item not in target_seq:
                if s_item not in candidate_movies_dict:
                    candidate_movies_dict[s_item] = 0.
                candidate_movies_dict[s_item] += is_v
#             print (item_id_list[is_i], candidate_movies_dict)
    candidate_pairs = list(sorted(candidate_movies_dict.items(), key=lambda x:x[-1], reverse=True))
#     print (candidate_pairs)
    candidate_items = [e[0] for e in candidate_pairs][:total_i]
#     print (candidate_items)
    return candidate_items

# %% [markdown]
# ## Candidate ids

# %%
'''
In order to economize, our initial step is to identify user sequences that exhibit a high probability
of obtaining accurate predictions from GPT-3.5 based on their respective candidates.
Subsequently, we proceed to utilize the GPT-3.5 API to generate predictions for these promising user sequences.
'''
results_data_15 = []
length_limit = length_limit
num_u= 12
total_i = num_cand
count = 0
total = 0
cand_ids = []

for i in id_list[:1000]:
    elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')

    candidate_items = sort_uf_items(seq_list, user_matrix_sim[i], num_u=num_u, num_i=total_i)

#     print (elem[-1], '-',seq_list[-1])
    if elem[-1] in candidate_items:
#         print ('HIT: 1')
        count += 1
        cand_ids.append(i)
    else:
        pass
#         print ('HIT: 0')
    total +=1

print (f'count/total:{count}/{total}={count*1.0/total}')
print ('-----------------\n')

# %%
cand_ids

# %% [markdown]
# ## Prompts

# %%
temp_1 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: What features are most important to me when selecting movies (Summarize my preferences briefly)?
Answer:
"""

temp_2 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: What features are most important to me when selecting movies (Summarize my preferences briefly)?
Answer: {}.
Step 2: Selecting the most featured movies from the watched movies according to my preferences (Format: [no. a watched movie.]).
Answer:
"""

temp_3 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: What features are most important to me when selecting movies (Summarize my preferences briefly)?
Answer: {}.
Step 2: Selecting the most featured movies (at most 5 movies) from the watched movies according to my preferences in descending order (Format: [no. a watched movie.]).
Answer: {}.
Step 3: Can you recommend 10 movies from the Candidate Set similar to the selected movies I've watched (Format: [no. a watched movie - a candidate movie])?.
Answer:
"""

# %% [markdown]
# ## Llama2

# %%
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_name = 'meta-llama/Llama-2-7b-chat-hf'

model = AutoModelForCausalLM.from_pretrained(model_name, load_in_4bit=True, device_map='auto')
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
pipeline = transformers.pipeline(
    model=model,
    tokenizer=tokenizer,
    return_full_text=True,
    task='text-generation',
    temperature=0.1,
    max_new_tokens=512,
    repetition_penalty=1.1
)

# %%
prompt = '''
Write a short poem about roses.
'''

res = pipeline(prompt)
print(res[0]['generated_text'])

# %% [markdown]
# ## QPs
#
# - Quais outras métricas podem ser utilizadas para avaliar a performance do sistema?
#
# - Posso sumarizar a peformance do sistema como um todo tirando a médida das métricas?
#
# - Preciso gerar várias API_KEYs?

# %% [markdown]
# ## Open models
#
# - Llama (next week)
# - Falcon (try)
# - Mistral (try)
#
# !Compare
